# %% [markdown]
# <a href="https://colab.research.google.com/github/mdeniz20/NLP-0/blob/main/search_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

os.environ["GOOGLE_CSE_ID"] = "95f0a1d44f4004362"
os.environ["GOOGLE_API_KEY"] = "AIzaSyBzgviH-yB9aAG5shU4-bJPi8dwWr5Rgp0"
os.environ["LANGCHAIN_API_KEY"] = "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"
os.environ["COHERE_API_KEY"] = "ivX0IquCfE4RSABYyNX7iPGWkssXk21hsgqaUvUC"
os.environ["TAVILY_API_KEY"] = "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"

# %%
# %pip install --upgrade --quiet  langchain-community
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.3/990.3 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.2/374.2 kB 14.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 2.9 MB/s eta 0:00:00

# %%
from langchain_community.utilities import GoogleSearchAPIWrapper
from langchain_core.tools import Tool

search = GoogleSearchAPIWrapper()

def search_web(search_query):
  search = GoogleSearchAPIWrapper()
  return search.run(search_query)

search_web("Who is obama")
# Out:
# "Barack Obama served as the 44th President of the United States. His story is the American story — values from the heartland, a middle-class upbringing in a\xa0... Today, we've also been reminded – again – that he's a patriot of the highest order. Photo shared by Obama Foundation on July 18, 2024 tagging @barackobama, and\xa0... Obama was born in Honolulu, Hawaii. He graduated from Columbia University in 1983 with a Bachelor of Arts degree in political science and later worked as a\xa0... It's our small way to honor the remarkable legacy of a gentle, courageous man who did as much as anyone to bring this country closer to our founding ideals. Obama was elected the first African-American president of the Harvard Law Review, prior to graduating magna cum laude in 1991. He returned to Chicago in 1992\xa0... Recent News ... Barack Obama (born August 4, 1961, Honolulu, Hawaii, U.S.) is the 44th president of the United States (2009–17) and the first African American to\xa0... President Barack Obama. President Obama. Barack Obama is the 44th President of the United States. His story is the American story -- values from the heartland,\xa0... There is absolutely no place for political violence in our democracy. Although we don't yet know exactly what happened, we should all be relieved that former\xa0... The Obama Presidential Center represents a historic opportunity to build a world-class museum and public gathering space that celebrates our nation's first\xa0... Welcome to the Office of Barack and Michelle Obama. We Love You Back. Play video. The Office of Barack and Michelle Obama · Obama Foundation. obama.org. © 2023\xa0..."

# %%
t
# Out:
# "1 Child's First Name. (Type or print). BARACK. CERTIFICATE OF LIVE BIRTH lb ... OBAMA, II. Day. 4. 6b. Island. Year. 5b. Hour. 1961 7:24 P.M.. Oahu. 6d. Is Place\xa0... As a member of the Democratic Party, he was the first African-American president in U.S. history. Obama previously served as a U.S. senator representing\xa0... First Lady Michelle LaVaughn Robinson Obama is a lawyer, writer, and the wife of the 44th President, Barack Obama. She is the first African-American First\xa0... A museum that asks you to believe—not just in President Obama's power to create change, but in your own. ... (All fields required.) First name. First name. Last\xa0... Dec 19, 2018 ... His full name is Barack Hussein Obama II. Since the “II” is simply because he was named for his father, his last name is Obama. Here's my full statement: My ... Michelle and I are proud that the plaza at the Obama Presidential Center will bear John's name, and honor his legacy. Michelle Robinson Obama was born in DeYoung, Illinois, on January 17, 1964, to parents Frasier Robinson III and Marian Shields. She grew up in Chicago's\xa0... Apr 2, 2018 ... Barack Hussein Obama's real name is Barack Hussein Obama II. He's named after his father, if I recall correctly. Apr 7, 2021 ... ... . Reply reply. Wildform22. •. Morons, Obama IS his last name, and his first name is President. Reply reply. masta_dizasta. •. Now i don't\xa0... Jan 19, 2017 ... Hopeful parents named their sons for the first Black president, whose name is a variation of the Hebrew name Baruch, which means “blessed”\xa0..."

# %%
# Modules
import imaplib
import email
from datetime import datetime
import pytz
from google.colab import userdata

# Credentials
username = "mibrdeniz@gmail.com"

# Generated app password
app_password = userdata.get("GMAIL_APP_PASSWORD")  # Replace with your actual app password

# IMAP host
gmail_host = 'imap.gmail.com'

# Set connection
mail = imaplib.IMAP4_SSL(gmail_host)

try:
    # Login
    mail.login(username, app_password)
except imaplib.IMAP4.error as e:
    print(f"Login failed: {e}")
    exit()

# Select inbox
status, _ = mail.select("INBOX")
if status != 'OK':
    print(f"Failed to select inbox: {status}")
    mail.logout()
    exit()

# Define Istanbul timezone
istanbul_tz = pytz.timezone('Europe/Istanbul')

# Get today's date in Istanbul timezone and convert to UTC
local_now = datetime.now(istanbul_tz)
utc_now = local_now.astimezone(pytz.UTC)
today_date_utc = utc_now.strftime("%d-%b-%Y")

# Print the date for debugging
print(f"Searching for emails on date: {today_date_utc}")

# Search for emails from today in UTC
try:
    status, selected_mails = mail.search(None, f'(ON "{today_date_utc}")')
    if status != 'OK':
        print(f"Failed to search emails: {status}")
        mail.logout()
        exit()
except imaplib.IMAP4.error as e:
    print(f"Error during search: {e}")
    mail.logout()
    exit()

# Total number of mails from today
print("Total Messages for today: ", len(selected_mails[0].split()))

for num in selected_mails[0].split():
    try:
        status, data = mail.fetch(num, '(RFC822)')
        if status != 'OK':
            print(f"Failed to fetch email {num}: {status}")
            continue

        _, bytes_data = data[0]

        # Convert the byte data to message
        email_message = email.message_from_bytes(bytes_data)
        print("\n===========================================")

        # Access data
        print("Subject: ", email_message["subject"])
        print("To:", email_message["to"])
        print("From: ", email_message["from"])
        print("Date: ", email_message["date"])

        for part in email_message.walk():
            if part.get_content_type() == "text/plain" or part.get_content_type() == "text/html":
                message = part.get_payload(decode=True)
                print("Message: \n", message.decode())
                print("==========================================\n")
                break
    except imaplib.IMAP4.error as e:
        print(f"Error during fetch: {e}")
        continue

# Logout
mail.logout()
# Out:
# Searching for emails on date: 31-Jul-2024
# Total Messages for today:  5
#
# ===========================================
# Subject:  88% off U - Super Saver Sale
# To: mibrdeniz@gmail.com
# From:  "Design.com" <maker@hello.design.com>
# Date:  Tue, 30 Jul 2024 21:26:11 +0000 (UTC)
# Message:
#  88% off for 72 hours only.
#
#
#
#
#
# Get a super logo at 88% off
#
#
#
# Hey Mahmut İbrahim - supercharge your brand with our Super Saver Sale with an electrifying offer 88% off your super logo.
#
#
#
# ===========================================
# Subject:  =?UTF-8?B?R8O8dmVubGlrIHV5YXLEsXPEsQ==?=
# To: mibrdeniz@gmail.com
# From:  Google <no-reply@accounts.google.com>
# Date:  Wed, 31 Jul 2024 05:52:23 GMT
# Message:
#  [image: Google]
# Windows cihazında yeni oturum açma işlemi
#
#
# mibrdeniz@gmail.com
# Windows cihazında Google Hesabınızda yeni bir oturum açma işlemi tespit
# ettik. Bu işlem size aitse herhangi bir şey yapmanız gerekmez. İşlem size
# ait değilse hesabınızı güven altına almanıza yardımcı oluruz.
# Etkinliği kontrol et
# <https://accounts.google.com/AccountChooser?Email=mibrdeniz@gmail.com&continue=https://myaccount.google.com/alert/nt/1722405143000?rfn%3D325%26rfnc%3D1%26eid%3D-5756786668591061202%26et%3D0>
# Güvenlik etkinliğini şu sayfada da görebilirsiniz:
# https://myaccount.google.com/notifications
# Bu e-posta sizi Google Hesabınız ve hizmetlerinizdeki önemli değişiklikler
# hakkında bilgilendirmek için gönderilmiştir.
# © 2024 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA
#
# ==========================================
#
#
# ===========================================
# Subject:  =?UTF-8?B?bWlicmRlbml6QGdtYWlsLmNvbSBpw6dpbiBnw7x2ZW5saWsgdXlhcsSxc8Sx?=
# To: maho0aga@hotmail.com
# From:  Google <no-reply@accounts.google.com>
# Date:  Wed, 31 Jul 2024 05:52:23 GMT
# Message:
#  Bu e-posta, mibrdeniz@gmail.com adresine gönderilen güvenlik uyarısının bir
# kopyasıdır. maho0aga@hotmail.com, bu hesabın kurtarma e-posta adresidir. Bu
# hesabı tanımıyorsanız silin
# <https://accounts.google.com/AccountDisavow?adt=AOX8kiq71m7Sz-6EAgDqufLbItsw5Fkwi6-ZX-oTDnFy2ZA71DECHZh9TAopsmA4FQ&rfn=325>
# .
# [image: Google]
# Windows cihazında yeni oturum açma işlemi
#
#
# mibrdeniz@gmail.com
# Windows cihazında Google Hesabınızda yeni bir oturum açma işlemi tespit
# ettik. Bu işlem size aitse herhangi bir şey yapmanız gerekmez. İşlem size
# ait değilse hesabınızı güven altına almanıza yardımcı oluruz.
# Etkinliği kontrol et
# <https://accounts.google.com/AccountChooser?Email=mibrdeniz@gmail.com&continue=https://myaccount.google.com/alert/nt/1722405143000?rfn%3D325%26rfnc%3D1%26eid%3D-5756786668591061202%26et%3D1>
# Güvenlik etkinliğini şu sayfada da görebilirsiniz:
# https://myaccount.google.com/notifications
# Bu e-posta sizi Google Hesabınız ve hizmetlerinizdeki önemli değişiklikler
# hakkında bilgilendirmek için gönderilmiştir.
# © 2024 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA
#
# ==========================================
#
#
# ===========================================
# Subject:  =?UTF-8?B?R8O8dmVubGlrIHV5YXLEsXPEsQ==?=
# To: mibrdeniz@gmail.com
# From:  Google <no-reply@accounts.google.com>
# Date:  Wed, 31 Jul 2024 05:54:49 GMT
# Message:
#  [image: Google]
# Hesabınızda oturum açmak için uygulama şifresi oluşturuldu
#
#
# mibrdeniz@gmail.com
# aigent için bu şifreyi siz oluşturmadıysanız birisi hesabınızı kullanıyor
# olabilir. Hesabınızı şimdi kontrol edip güvenliğini sağlayın.
# Etkinliği kontrol et
# <https://accounts.google.com/AccountChooser?Email=mibrdeniz@gmail.com&continue=https://myaccount.google.com/alert/nt/1722405289411?rfn%3D20%26rfnc%3D1%26eid%3D-5927775069364547520%26et%3D0>
# Güvenlik etkinliğini şu sayfada da görebilirsiniz:
# https://myaccount.google.com/notifications
# Bu e-posta sizi Google Hesabınız ve hizmetlerinizdeki önemli değişiklikler
# hakkında bilgilendirmek için gönderilmiştir.
# © 2024 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA
#
# ==========================================
#
#
# ===========================================
# Subject:  =?UTF-8?B?bWlicmRlbml6QGdtYWlsLmNvbSBpw6dpbiBnw7x2ZW5saWsgdXlhcsSxc8Sx?=
# To: maho0aga@hotmail.com
# From:  Google <no-reply@accounts.google.com>
# Date:  Wed, 31 Jul 2024 05:54:49 GMT
# Message:
#  Bu e-posta, mibrdeniz@gmail.com adresine gönderilen güvenlik uyarısının bir
# kopyasıdır. maho0aga@hotmail.com, bu hesabın kurtarma e-posta adresidir. Bu
# hesabı tanımıyorsanız silin
# <https://accounts.google.com/AccountDisavow?adt=AOX8kioUbWFbZGJrLj3LWn-ulJc4nUpJ3BtZL9OS8C8A-PV2Q7cDl1NLPYLc1dxj5Q&rfn=20>
# .
# [image: Google]
# Hesabınızda oturum açmak için uygulama şifresi oluşturuldu
#
#
# mibrdeniz@gmail.com
# aigent için bu şifreyi siz oluşturmadıysanız birisi hesabınızı kullanıyor
# olabilir. Hesabınızı şimdi kontrol edip güvenliğini sağlayın.
# Etkinliği kontrol et
# <https://accounts.google.com/AccountChooser?Email=mibrdeniz@gmail.com&continue=https://myaccount.google.com/alert/nt/1722405289411?rfn%3D20%26rfnc%3D1%26eid%3D-5927775069364547520%26et%3D1>
# Güvenlik etkinliğini şu sayfada da görebilirsiniz:
# https://myaccount.google.com/notifications
# Bu e-posta sizi Google Hesabınız ve hizmetlerinizdeki önemli değişiklikler
# hakkında bilgilendirmek için gönderilmiştir.
# © 2024 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA
#
# ==========================================
# ('BYE', [b'LOGOUT Requested'])

# %%
class Environment:
  def set_env(self):
    path = os.path.join(os.getcwd(), "security_keys")
    if not os.path.exists(path):
      os.mkdir(path)
    email_security_keys_path = os.path.join(path, "email.txt")
    if not os.path.exists(email_security_keys_path):
      with open(email_security_keys_path, "w") as f:
        f.write("mibrdeniz@gmail.com\n"+userdata.get("GMAIL_APP_PASSWORD"))
env = Environment()
env.set_env()

# %%
import os
import imaplib
import email
from datetime import datetime
import pytz
from binascii import Error  # Not needed unless you're working with binary data; consider removing if not used

class EmailHandler:

    class EmailHost:
        host = {
            "GMAIL": "imap.gmail.com",
            "OUTLOOK": "outlook.office365.com",
            "HOTMAIL": "outlook.live.com"
        }

    def __init__(self, email: str = None, password: str = None, file_path: str = None, host: str = "GMAIL"):
        self.email = email
        self.password = password
        self.file_path = file_path

        if not email and not password:
            self.email, self.password, self.file_path = self._get_email_details_from_file(file_path)

        if not self.email or not self.password:
            raise ValueError("Email or password not set")

        host = host.upper()
        if host not in self.EmailHost.host:
            raise ValueError(f"Host {host} not supported")
        self.mail_host = self.EmailHost.host[host]

        self.mail = None

    def _login(self):
        self.mail = imaplib.IMAP4_SSL(self.mail_host)
        try:
            # Login
            self.mail.login(self.email, self.password)
        except imaplib.IMAP4.error as e:
            raise Error(f"Login failed: {e}")

        status, _ = self.mail.select("INBOX")
        if status != 'OK':
            self.mail.logout()
            raise Error(f"Failed to select inbox: {status}")

    def _get_email_details_from_file(self, file_path: str):
        if not file_path:
            path = os.path.join(os.getcwd(), "security_keys")
            email_security_keys_path = os.path.join(path, "email.txt")
        else:
            email_security_keys_path = file_path

        if not os.path.exists(email_security_keys_path):
            raise FileNotFoundError(f"Security keys file not found {email_security_keys_path}")

        with open(email_security_keys_path, "r") as f:
            lines = f.readlines()
            email = lines[0].strip()
            password = lines[1].strip()
        return email, password, email_security_keys_path

    def get_todays_emails(self)->list:
        self._login()
        mail_list = []
        istanbul_tz = pytz.timezone('Europe/Istanbul')

        # Get today's date in Istanbul timezone and convert to UTC
        local_now = datetime.now(istanbul_tz)
        utc_now = local_now.astimezone(pytz.UTC)
        today_date_utc = utc_now.strftime("%d-%b-%Y")

        try:
            # Search for emails from today in UTC
            status, selected_mails = self.mail.search(None, f'(ON "{today_date_utc}")')
            if status != 'OK':
                raise Error(f"Failed to search emails: {status}")

            # Total number of mails from today
            num_of_mails = len(selected_mails[0].split())
            counter = 1

            for num in selected_mails[0].split():
                try:
                    status, data = self.mail.fetch(num, '(RFC822)')
                    if status != 'OK':
                        raise Error(f"Failed to fetch email {num}: {status}")

                    _, bytes_data = data[0]
                    email_message = email.message_from_bytes(bytes_data)

                    subject = email_message.get('subject', '')
                    to = email_message.get('to', '')
                    from_ = email_message.get('from', '')
                    date = email_message.get('date', '')

                    body = ""
                    for part in email_message.walk():
                        if part.get_content_type() in ("text/plain", "text/html"):
                            message = part.get_payload(decode=True)
                            body = message.decode()
                            break

                    _mail = {
                        "subject": subject,
                        "to": to,
                        "from": from_,
                        "date": date,
                        "body": body
                    }
                    mail_list.append(_mail)

                except imaplib.IMAP4.error as e:
                    print(f"Error during fetch: {e}")
                    continue

        except imaplib.IMAP4.error as e:
            print(f"Error during search: {e}")

        finally:
            if self.mail:
                self.mail.logout()

        return mail_list

    def __del__(self):
        # Ensure logout is called when the object is being destroyed
        if self.mail:
            self.mail.logout()

# %%
email_handler = EmailHandler()

# %%
emails = email_handler.get_todays_emails()

# %%
print(str(len(emails)))
emails.reverse()
for elem in emails:
  print("$"*80)
  print(elem)
# Out:
# 6
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# {'subject': '=?utf-8?B?QmXEn2VuZGnEn2luaXogYmlyIGfDtnLDvG50w7xuw7xuIMOnZQ==?=\r\n =?utf-8?B?xZ9pdGxlbWVsZXJpbmkgb2x1xZ90dXJ1bg==?=', 'to': '<maho0aga@hotmail.com>', 'from': '"Adobe Creative Cloud" <mail@mail.adobe.com>', 'date': 'Wed, 31 Jul 2024 00:05:20 -0700', 'body': '\r\n\r\n\r\n\r\n------------------------------------------------------------------------\r\n\r\nView web version:\r\nhttps://t-info.mail.adobe.com/r/?id=t4b8ea7b9,fd901202,bfba095a&e=cDE9JTQwT0U3bmdNaGdUVHRHaTJUMTZ3N0x4YyUyRnRYSjZBTXc3UElMM0NWYW9qUWJ3JTNE&s=FhQesysmkF1Dj_vZUk_wn3yfpPXtf4wVSdg3cNmhLHo\r\n\r\n------------------------------------------------------------------------\r\n\r\nUnfortunately, your email client cannot display HTML, or your settings\r\nare turned off. To view this email, please click the link above, or\r\ncopy and paste it into your browser.\r\n\r\n------------------------------------------------------------------------\r\n\r\nAdobe, the Adobe logo, Creative Cloud, the Creative Cloud logo,\r\nLightroom and Photoshop are either registered trademarks or\r\ntrademarks of Adobe in the United States\r\nand/or other countries. All other trademarks are the property of\r\ntheir respective owners.\r\n\r\n\r\nThis is a marketing email from Adobe Systems Software Ireland Limited,\r\n4-6 Riverwalk, Citywest Business Park, Dublin 24, Ireland.\r\n\r\nClick on the following link to unsubscribe, or send us an unsubscribe \r\nrequest to the postal address above.\r\nUnsubscribe:\r\n https://t-info.mail.adobe.com/r/?id=t4b8ea7b9,fd901202,bfba095b&e=cDE9JTQwamE1ellzaWhkdHdId1YwcjZ3ZUNvSjd6STFoYUJBY04wY3ppdUcwMTdBRSUzRCZwMj0mbG9jPWVuJnAzPTIw&s=eoL-GTBwKgrSBCc84YsAn5BcJOehWajab7iDEH3Ga_Y \r\n\r\nYour privacy is important to us. Please review the Adobe Privacy Policy.\r\nhttps://t-info.mail.adobe.com/r/?id=t4b8ea7b9,fd901202,bfba095c\r\n\r\nTo ensure email delivery, add mail@mail.adobe.com to your \r\naddress book, contacts or safe sender list.\r\n\r\nPlease do not reply to this message. To contact Adobe, find options \r\nonline or call 0207 365 0735.\r\nhttps://t-info.mail.adobe.com/r/?id=t4b8ea7b9,fd901202,bfba095d\r\n\r\nRegistered office: Adobe Systems Software Ireland Limited,\r\n4-6 Riverwalk, Citywest Business Park, Dublin 24, Ireland.\r\nRegistered number: 344992\r\n\r\n\r\n'}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# {'subject': '=?UTF-8?B?bWlicmRlbml6QGdtYWlsLmNvbSBpw6dpbiBnw7x2ZW5saWsgdXlhcsSxc8Sx?=', 'to': 'maho0aga@hotmail.com', 'from': 'Google <no-reply@accounts.google.com>', 'date': 'Wed, 31 Jul 2024 05:54:49 GMT', 'body': 'Bu e-posta, mibrdeniz@gmail.com adresine gönderilen güvenlik uyarısının bir\r\nkopyasıdır. maho0aga@hotmail.com, bu hesabın kurtarma e-posta adresidir. Bu\r\nhesabı tanımıyorsanız silin\r\n<https://accounts.google.com/AccountDisavow?adt=AOX8kioUbWFbZGJrLj3LWn-ulJc4nUpJ3BtZL9OS8C8A-PV2Q7cDl1NLPYLc1dxj5Q&rfn=20>\r\n.\r\n[image: Google]\r\nHesabınızda oturum açmak için uygulama şifresi oluşturuldu\r\n\r\n\r\nmibrdeniz@gmail.com\r\naigent için bu şifreyi siz oluşturmadıysanız birisi hesabınızı kullanıyor\r\nolabilir. Hesabınızı şimdi kontrol edip güvenliğini sağlayın.\r\nEtkinliği kontrol et\r\n<https://accounts.google.com/AccountChooser?Email=mibrdeniz@gmail.com&continue=https://myaccount.google.com/alert/nt/1722405289411?rfn%3D20%26rfnc%3D1%26eid%3D-5927775069364547520%26et%3D1>\r\nGüvenlik etkinliğini şu sayfada da görebilirsiniz:\r\nhttps://myaccount.google.com/notifications\r\nBu e-posta sizi Google Hesabınız ve hizmetlerinizdeki önemli değişiklikler\r\nhakkında bilgilendirmek için gönderilmiştir.\r\n© 2024 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA\r\n'}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# {'subject': '=?UTF-8?B?R8O8dmVubGlrIHV5YXLEsXPEsQ==?=', 'to': 'mibrdeniz@gmail.com', 'from': 'Google <no-reply@accounts.google.com>', 'date': 'Wed, 31 Jul 2024 05:54:49 GMT', 'body': '[image: Google]\r\nHesabınızda oturum açmak için uygulama şifresi oluşturuldu\r\n\r\n\r\nmibrdeniz@gmail.com\r\naigent için bu şifreyi siz oluşturmadıysanız birisi hesabınızı kullanıyor\r\nolabilir. Hesabınızı şimdi kontrol edip güvenliğini sağlayın.\r\nEtkinliği kontrol et\r\n<https://accounts.google.com/AccountChooser?Email=mibrdeniz@gmail.com&continue=https://myaccount.google.com/alert/nt/1722405289411?rfn%3D20%26rfnc%3D1%26eid%3D-5927775069364547520%26et%3D0>\r\nGüvenlik etkinliğini şu sayfada da görebilirsiniz:\r\nhttps://myaccount.google.com/notifications\r\nBu e-posta sizi Google Hesabınız ve hizmetlerinizdeki önemli değişiklikler\r\nhakkında bilgilendirmek için gönderilmiştir.\r\n© 2024 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA\r\n'}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# {'subject': '=?UTF-8?B?bWlicmRlbml6QGdtYWlsLmNvbSBpw6dpbiBnw7x2ZW5saWsgdXlhcsSxc8Sx?=', 'to': 'maho0aga@hotmail.com', 'from': 'Google <no-reply@accounts.google.com>', 'date': 'Wed, 31 Jul 2024 05:52:23 GMT', 'body': 'Bu e-posta, mibrdeniz@gmail.com adresine gönderilen güvenlik uyarısının bir\r\nkopyasıdır. maho0aga@hotmail.com, bu hesabın kurtarma e-posta adresidir. Bu\r\nhesabı tanımıyorsanız silin\r\n<https://accounts.google.com/AccountDisavow?adt=AOX8kiq71m7Sz-6EAgDqufLbItsw5Fkwi6-ZX-oTDnFy2ZA71DECHZh9TAopsmA4FQ&rfn=325>\r\n.\r\n[image: Google]\r\nWindows cihazında yeni oturum açma işlemi\r\n\r\n\r\nmibrdeniz@gmail.com\r\nWindows cihazında Google Hesabınızda yeni bir oturum açma işlemi tespit\r\nettik. Bu işlem size aitse herhangi bir şey yapmanız gerekmez. İşlem size\r\nait değilse hesabınızı güven altına almanıza yardımcı oluruz.\r\nEtkinliği kontrol et\r\n<https://accounts.google.com/AccountChooser?Email=mibrdeniz@gmail.com&continue=https://myaccount.google.com/alert/nt/1722405143000?rfn%3D325%26rfnc%3D1%26eid%3D-5756786668591061202%26et%3D1>\r\nGüvenlik etkinliğini şu sayfada da görebilirsiniz:\r\nhttps://myaccount.google.com/notifications\r\nBu e-posta sizi Google Hesabınız ve hizmetlerinizdeki önemli değişiklikler\r\nhakkında bilgilendirmek için gönderilmiştir.\r\n© 2024 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA\r\n'}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# {'subject': '=?UTF-8?B?R8O8dmVubGlrIHV5YXLEsXPEsQ==?=', 'to': 'mibrdeniz@gmail.com', 'from': 'Google <no-reply@accounts.google.com>', 'date': 'Wed, 31 Jul 2024 05:52:23 GMT', 'body': '[image: Google]\r\nWindows cihazında yeni oturum açma işlemi\r\n\r\n\r\nmibrdeniz@gmail.com\r\nWindows cihazında Google Hesabınızda yeni bir oturum açma işlemi tespit\r\nettik. Bu işlem size aitse herhangi bir şey yapmanız gerekmez. İşlem size\r\nait değilse hesabınızı güven altına almanıza yardımcı oluruz.\r\nEtkinliği kontrol et\r\n<https://accounts.google.com/AccountChooser?Email=mibrdeniz@gmail.com&continue=https://myaccount.google.com/alert/nt/1722405143000?rfn%3D325%26rfnc%3D1%26eid%3D-5756786668591061202%26et%3D0>\r\nGüvenlik etkinliğini şu sayfada da görebilirsiniz:\r\nhttps://myaccount.google.com/notifications\r\nBu e-posta sizi Google Hesabınız ve hizmetlerinizdeki önemli değişiklikler\r\nhakkında bilgilendirmek için gönderilmiştir.\r\n© 2024 Google LLC, 1600 Amphitheatre Parkway, Mountain View, CA 94043, USA\r\n'}
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# {'subject': '88% off U - Super Saver Sale', 'to': 'mibrdeniz@gmail.com', 'from': '"Design.com" <maker@hello.design.com>', 'date': 'Tue, 30 Jul 2024 21:26:11 +0000 (UTC)', 'body': "88% off for 72 hours only.\r\n\r\n\r\n\r\n\r\n\r\nGet a super logo at 88% off\r\n\r\n\r\n\r\nHey Mahmut İbrahim - supercharge your brand with our Super Saver Sale with an electrifying offer 88% off your super logo.\r\n\r\nhttps://ablink.hello.design.com/ls/click?upn=u001.iBoCFi55klH73Tcle37zkU9aCtnbk0gJ7o3Id-2BOI4YyFQXV2oC2rKDqZsH8TYB-2BhpbPY7Weg95RAybUQEu9kIKxcy7wVRP92KDEXLox7Xjg5ppxqF0lAhOeU54h7FtM0ufurRcvh-2FkZMOCdVbky1vuK5H-2F7YBAVf-2F3IK1pl-2B323pXIl0bicIaDn9C74WXzyUyeO6DjP2B-2BAkCcPPaw2JDrvcS5-2FQfrMAyVzqTK0GrMceqFC8mdM36RXQkiHhDORW3Gq5mmA1r8MFcnTwKL28c8WmZmACa-2FgN7CHXFCMYAfWyj8SJKOqqUojGFWKdcpevkhSDXYqGdAEyxEhJOYhlfIx7utMuIiREXd81jTtoKebnEq8i3kdgEwix3O0nJsmc3lJbwLM6Oqy8u1PJuU0F5rXvtn0wdowYW7gx-2FuD9-2FtUqrUYJiE7mTpWcWbxXz-2BwrqFv5PGiq2EwFKXi524vfIhSVoRI1c9db3p-2B0Ok3RdpM-3D-f8P_vTNRKGdXjEoLbSdvSR7GEh8sPFAkstQN5-2Bm-2Fh9O1f43UhnZY4N1fGnzRfW0tm1pOAx-2F6E0566ilty6yzH46VcrC5dnEbVyyIMBm4hDGDjAgO2gaYlg9AN0vG58dPq42-2Blg-2FdvMjhjC8oiyIfg-2FK5G6aCstNenMHIlUsG0tfykmhM-2FW1W7R7eoPvh8NKxYg2BHqGTvJXuMAw6ZhWw-2FTeG8GciB46VcegHGPXW9LaJmdPJ1lp
tXjKQtSjR4OvhQUJmPrjobwcYk5IotLFN3I247b98EK7ehQ0ccsFfSd2XLC75r92WVPLmOmO0RLKLPrkBdoqP72mUYx0I-2BvKTwUBwp8at8PEYF4WrQMVOlMqaqPf1wgTep4WXEMo3b5Mqwx8mchWgMKt-2BgAo4U7tHDnvzY0Jo6kr2ZdqZQctLB6pzXBzUo1oR3dnqnSecdhXMPgYDj-2BvfuK5YyYrwHRh4BwdRLWfV-2BXAdQhbvk-3D\r\n\r\n\r\n\r\nThis offer won't last long. Simply download your logo for U before Saturday, 3 August and take your brand to the next level.\r\n\r\n\r\n\r\nSuper toolkit to build a super brand   \r\n\r\nLaunch your business with our all-in-one design platform. Download your logo today and get full access to our toolkit:\r\n \r\n* 1-Page and Advanced Website builders with branded addresses\r\n* Branded social media designs for Instagram, Facebook and more\r\n* Business card templates already branded with your logo + colours\r\n* Print designs including flyers, posters and postcards\r\n* Business assets including invoices, email signatures, and more\r\n\r\n\r\n\r\nGET YOUR LOGO:\r\n\r\nhttps://ablink.hello.design.com/ls/click?upn=u001.iBoCFi55klH73Tcle37zkU9aCtnbk0gJ7o3Id-2BOI4YyFQXV2oC2rKDqZsH8TYB-2BhpbPY7Weg95RAybUQEu9kIKxcy7wVRP92KDEXLox7Xjg5ppxqF0lAhOeU54h7FtM0 ...

# %%
e FileNotFoundError(f"Security keys file not found {email_security_keys_path}")

      with open(email_security_keys_path, "r") as f:
          lines = f.readlines()
          email = lines[0].strip()
          password = lines[1].strip()
      return email, password, email_security_keys_path

  def get_todays_emails(self)->list:
      self._login()
      mail_list = []
      istanbul_tz = pytz.timezone('Europe/Istanbul')

      # Get today's date in Istanbul timezone and convert to UTC
      local_now = datetime.now(istanbul_tz)
      utc_now = local_now.astimezone(pytz.UTC)
      today_date_utc = utc_now.strftime("%d-%b-%Y")

      try:
          # Search for emails from today in UTC
          status, selected_mails = self.mail.search(None, f'(ON "{today_date_utc}")')
          if status != 'OK':
              raise Error(f"Failed to search emails: {status}")

          # Total number of mails from today
          num_of_mails = len(selected_mails[0].split())
          counter = 1

          for num in selected_mails[0].split():
              try:
                  status, data = self.mail.fetch(num, '(RFC822)')
                  if status != 'OK':
                      raise Error(f"Failed to fetch email {num}: {status}")

                  _, bytes_data = data[0]
                  email_message = email.message_from_bytes(bytes_data)

                  subject = email_message.get('subject', '')
                  to = email_message.get('to', '')
                  from_ = email_message.get('from', '')
                  date = email_message.get('date', '')

                  body = ""
                  for part in email_message.walk():
                      if part.get_content_type() in ("text/plain", "text/html"):
                          message = part.get_payload(decode=True)
                          body = message.decode()
                          break

                  _mail = {
                      "subject": subject,
                      "to": to,
                      "from": from_,
                      "date": date,
                      "body": body
                  }
                  mail_list.append(_mail)

              except imaplib.IMAP4.error as e:
                  print(f"Error during fetch: {e}")
                  continue

      except imaplib.IMAP4.error as e:
          print(f"Error during search: {e}")

      finally:
          if self.mail:
              self.mail.logout()

      return mail_list

  def __del__(self):
      # Ensure logout is called when the object is being destroyed
      if self.mail:
          self.mail.logout()
